# %%
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# %%
#path ='/content/drive/MyDrive/IU'
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
# %matplotlib inline

root_dir = '/content/drive/MyDrive/BP'

possible_img_extension =['.jpg','.jpeg','.JPG','.png','.bmp']

face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_default.xml')


for(root, dirs, files) in os.walk(root_dir):
  if len(files) > 0:
    for file_name in files:
            if os.path.splitext(file_name)[1] in possible_img_extension:
                current_dir =root[len(root_dir)+1:]#디렉토리
                current_uuid =file_name[:file_name.find('-original')]#uuid
                print('/content/drive/MyDrive/newpic/%s'%current_dir)
                createFolder('/content/drive/MyDrive/newpic/%s'%current_dir)
                img_path = root + '/' + file_name
                
                img_path = img_path.replace('\\', '/') # \는 \\로 나타내야함         
                image = cv2.imread(img_path, cv2.IMREAD_COLOR)
                
                grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                faces = face_cascade.detectMultiScale(grayImage, 1.03, 5)
                print(faces)

                if(len(faces) ==1):
                  for (x,y,w,h) in faces:
                      newY = y-(h//3)
                      newYH = y+h+(h//3)
                      newX = x-(h//3)
                      newXH = x+h+(h//3)
                      if(newY <0):
                        newY =0
                      if(newX<0):
                        newX =0

                      cutting_img=image[newY:newYH, newX:newXH]
                  count += 1
                  plt.figure(figsize=(12,12))
                  image = cv2.cvtColor(cutting_img, cv2.COLOR_BGR2RGB)
                  # plt.imshow(image)
                  plt.imsave('/content/drive/MyDrive/newpic/%s/%s-sqaure.jpg'%(current_dir,current_uuid),image)

                  # plt.xticks([]), plt.yticks([])
                  # plt.show()
  print(count)
# Out:
# 66
# 66
# /content/drive/MyDrive/newpic/송혜교
# [[ 43  74 196 196]
#  [328  68 195 195]
#  [ 87 229 119 119]]
# /content/drive/MyDrive/newpic/송혜교
# [[595  71  66  66]
#  [822  70 149 149]
#  [ 30  78 138 138]
#  [315  74 168 168]]
# /content/drive/MyDrive/newpic/송혜교
# [[ 87 101 232 232]]
# /content/drive/MyDrive/newpic/송혜교
# [[476  95  30  30]
#  [375  49  60  60]
#  [425 132 108 108]
#  [211  69 135 135]]
# /content/drive/MyDrive/newpic/송혜교
# [[282  44 276 276]]
# /content/drive/MyDrive/newpic/송혜교
# [[ 70 114 233 233]]
# /content/drive/MyDrive/newpic/송혜교
# [[ 32 143 311 311]]
# /content/drive/MyDrive/newpic/송혜교
# [[151  26 165 165]]
# /content/drive/MyDrive/newpic/송혜교
# [[131 161  78  78]
#  [173 154 116 116]
#  [220 246  62  62]]
# /content/drive/MyDrive/newpic/송혜교
# [[152 158 266 266]
#  [423 140 111 111]]
# /content/drive/MyDrive/newpic/송혜교
# [[207  57 140 140]]
# /content/drive/MyDrive/newpic/송혜교
# [[239  83 169 169]
# ...
